# %% [markdown]
# <a href="https://colab.research.google.com/github/CSheppardCodes/HFTransformersLangPortal/blob/main/TranslationDatasetImport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 431 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 69 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 4.9 MB 20.3 MB/s
# ...
#      |████████████████████████████████| 115 kB 44.9 MB/s
# ...
#      |████████████████████████████████| 212 kB 64.8 MB/s
# ...
#      |████████████████████████████████| 163 kB 50.5 MB/s
# ...
#      |████████████████████████████████| 127 kB 56.4 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 38.4 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 51.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %% [markdown]
# #KDE4 dataset
# we can possibly use t5 1billlion
# gpt2

# %%
from datasets import load_dataset

raw_datasets = load_dataset("kde4", lang1="en", lang2="es")
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:97: FutureWarning: Deprecated argument(s) used in 'dataset_info': token. Will not be supported from version '0.12'.
#   warnings.warn(message, FutureWarning)
# WARNING:datasets.builder:Using custom data configuration en-es-lang1=en,lang2=es
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset kde4 downloaded and prepared to /root/.cache/huggingface/datasets/kde4/en-es-lang1=en,lang2=es/0.0.0/243129fb2398d5b0b4f7f6831ab27ad84774b7ce374cf10f60f6e1ff331648ac. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 218655
#     })
# })

# %%
split_datasets = raw_datasets["train"].train_test_split(train_size=0.9, seed=20)
split_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 196789
#     })
#     test: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 21866
#     })
# })

# %%
split_datasets["validation"] = split_datasets.pop("test")

# %%
split_datasets["train"][69]["translation"]
# Out:
# {'en': 'Threads With Own Articles',
#  'es': 'Hilos de conversación con artículos propios'}

# %%
from transformers import pipeline

model_checkpoint = "Helsinki-NLP/opus-mt-en-es"
translator = pipeline("translation", model=model_checkpoint)
translator("Default to expanded threads")
# Out:
# Downloading:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/312M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/826k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# [{'translation_text': 'Predeterminado a los hilos de discusión expandidos'}]
